# %% [markdown]
# <a href="https://colab.research.google.com/github/anajuliaanicheski/python/blob/main/aula_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula 1

# %%
print("I competição de programação dá Start")
# Out:
# I competição de programação dá Start

# %%
ano = "VI"

# %%
print(ano, "competição de programação da Start")
# Out:
# II competição de programação da Start

# %% [markdown]
# aula2

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo= livro_ficcao + livro_n_ficcao + livro_infantil
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
pontos_ana = 2* livro_ficcao + 5* livro_infantil
print(f"Os pontos totais de ana são {pontos_ana}")
pontos_carlos = 1 * livro_ficcao + 3 * livro_n_ficcao + 3 * livro_infantil
print(f"Os pontos totais de carlos são {pontos_carlos}")
pontos_totais = pontos_rodrigo + pontos_ana + pontos_carlos
print(f"Os pontos totais de ana e rodrigo e carlos são {pontos_totais}")
# Out:
# Os pontos totais do Rodrigo são 24
# Os pontos totais de ana são 46
# Os pontos totais de carlos são 56
# Os pontos totais de ana e rodrigo e carlos são 126

# %%
total_de_figurinhas = int(input("Digite o total de figurinhas: "))
numero_de_amigos = int(input("Digite o número de amigos: "))
figurinhas_amigo = total_de_figurinhas // (numero_de_amigos + 2)
figurinhas_joao = 2 * figurinhas_amigo

print(f"João recebeu {figurinhas_joao} figurinhas")
# Out:
# Digite o total de figurinhas: 200
# Digite o número de amigos: 8
# João recebeu 40 figurinhas

# %% [markdown]
# Aula 3

# %%
numero_de_alunos = int(input("Digite a quantidade de alunos: "))
numero_de_monitores = int(input("Digite a quantidade de monitores: "))
if numero_de_alunos + numero_de_monitores <= 50:
 resposta_positiva = "pode ir"
resposta_negativa = "não pode ir"
if numero_de_alunos + numero_de_monitores <= 50:
  print(resposta_positiva)
else:
  print(resposta_negativa)
# Out:
# Digite a quantidade de alunos: 30
# Digite a quantidade de monitores: 5
# pode ir

# %%
quantidades_professores = 8
numero_de_alunos = int(input("Digite a quantidade de alunos: "))
numero_de_monitores = int(input("Digite a quantidade de monitores: "))
if numero_de_alunos + numero_de_monitores + quantidades_professores <= 30:
 resposta_positiva = "pode ir"
resposta_negativa = "não pode ir"
if numero_de_alunos + numero_de_monitores + quantidades_professores <= 30:
  print(resposta_positiva)
else:
  print(resposta_negativa)
# Out:
# Digite a quantidade de alunos: 15
# Digite a quantidade de monitores: 8
# não pode ir

# %% [markdown]
# aula4

# %%
P = int(input("Digite a posição da porta P (0 ou 1): "))
R = int(input("Digite a posição da porta R (0 ou 1): "))
if P == 0:
    print("C")
elif R == 1:
    print("A")
else:
    print("B")
# Out:
# Digite a posição da porta P (0 ou 1): 1
# Digite a posição da porta R (0 ou 1): 0
# B

# %%
P = int(input("Digite a posição da porta P (0 ou 1): "))
R = int(input("Digite a posição da porta R (0 ou 1): "))
Q = int(input("Digite a posição da porta Q (0 ou 1): "))
if P == 0:
    print("C")
elif R == 1:
    print("A")
else:
    print("B")
if Q == 1:
    print("D")
# Out:
# Digite a posição da porta P (0 ou 1): 0
# Digite a posição da porta R (0 ou 1): 1
# Digite a posição da porta Q (0 ou 1): 1
# C
# D

# %% [markdown]
# aula6

# %%
def calcula_idade_maior(idade_monica, idade_filho1, idade_filho2):
  idade_filho3 = idade_monica - idade_filho1 - idade_filho2
  idade_maxima = max(idade_filho1, idade_filho2, idade_filho3)
  return idade_filho3, idade_maxima

# %% [markdown]
# aula7

# %% [markdown]
# aula8 ♑ ✨ 💯

# %%
from ctypes import pythonapi
print("sou seu assistente virtual,\n")
nome = input("digite seu nome: ")
print(f"Olà, {nome}. Qual è a sua duvida hoje ?")
resposta = input(" Qual o assunto que deseja tratar : matematica , python , javascript ").lower()
print(f"Que bom, {nome}, vamos falar sobre {resposta}")
if resposta == "javascript" :
  print("Òtimo, vamos falar sobre javascript. JavaScript (JS) é uma das linguagens de programação mais essenciais e amplamente utilizadas no mundo. Inicialmente criada em 1995 por Brendan Eich na Netscape, seu propósito original era adicionar interatividade básica às páginas web, que antes eram estáticas (feitas apenas com HTML e CSS).")
elif resposta == "python" :
  print("òtimo vamos falar sobre python. Python é uma das linguagens de programação mais populares e influentes do mundo. Criada por Guido van Rossum e lançada pela primeira vez em 1991, ela foi projetada com uma filosofia que prioriza a legibilidade do código, o que a torna extremamente amigável para iniciantes e muito eficiente para o desenvolvimento rápido.")
elif resposta == "matematica" :
  print(" otimo vamos falar sobre matematica . A Matemática é muito mais do que apenas números e fórmulas; é uma ciência fundamental que permeia praticamente todos os aspectos do nosso cotidiano e do mundo ao nosso redor. Desde as ações mais simples, como calcular um troco no supermercado, medir ingredientes em uma receita ou estimar o tempo de uma viagem, até as grandes inovações tecnológicas e descobertas científicas, a Matemática se mostra essencial.")
# Out:
# sou seu assistente virtual,
#
# digite seu nome: a
# Olà, a. Qual è a sua duvida hoje ?
#  Qual o assunto que deseja tratar : matematica , python , javascript PYThon
# Que bom, a, vamos falar sobre python
# òtimo vamos falar sobre python. Python é uma das linguagens de programação mais populares e influentes do mundo. Criada por Guido van Rossum e lançada pela primeira vez em 1991, ela foi projetada com uma filosofia que prioriza a legibilidade do código, o que a torna extremamente amigável para iniciantes e muito eficiente para o desenvolvimento rápido.
